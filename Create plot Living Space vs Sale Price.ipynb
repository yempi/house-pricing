# %% [markdown]
# ## Create plot Living Space vs Sale Price

# %% [markdown]
# ### with linear regresion line

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Open file
file_path = 'data_for_page2.csv'
df = pd.read_csv(file_path)
df
# Out:
#       OverallCond  HeatingQC   GrLivArea  FullBath  BedroomAbvGr  KitchenQual  \
# 0               5          5  158.862876         2             3            4
# 1               8          5  117.242661         2             3            3
# 2               5          5  165.923449         2             3            4
# 3               5          4  159.513192         1             3            4
# 4               5          5  204.199182         2             4            4
# ...           ...        ...         ...       ...           ...          ...
# 1455            5          5  153.010033         2             3            3
# 1456            6          3  192.586399         2             3            3
# 1457            9          5  217.391304         2             4            4
# 1458            6          4  100.148644         1             2            4
# 1459            6          4  116.685247         1             3            3
#
#       GarageCars   SalePrice
# 0              2  4142895.00
# 1              2  3606405.00
# 2              2  4440945.00
# 3              3  2781800.00
# 4              3  4967500.00
# ...          ...         ...
# 1455           2  3477250.00
# 1456           2  4172700.00
# 1457           1  5295355.00
# 1458           1  2824023.75
# 1459           1  2930825.00
#
# [1460 rows x 8 columns]

# %%
## Add first 50 to a dataframe
df2= df.head(50)

# %%
# Create x variable
x =df2['GrLivArea']
x
# Out:
# 0     158.862876
# 1     117.242661
# 2     165.923449
# 3     159.513192
# 4     204.199182
# 5     126.532887
# 6     157.376440
# 7     194.165738
# 8     164.808621
# 9     100.055741
# 10     96.618357
# 11    215.904868
# 12     84.726867
# 13    138.795987
# 14    116.406540
# 15     79.338536
# 16     93.273876
# 17    120.401338
# 18    103.493125
# 19    124.396135
# 20    220.735786
# 21    102.935712
# 22    166.759569
# 23     98.476403
# 24     98.476403
# 25    148.643627
# 26     83.612040
# 27    158.305463
# 28    148.643627
# 29     48.309179
# 30    122.352285
# 31    114.083984
# 32    114.641397
# 33    157.933854
# 34    145.020438
# 35    227.796358
# 36    101.913787
# 37    120.494240
# 38     98.197696
# 39    107.023411
# 40    123.002601
# 41    123.374210
# 42     82.125604
# 43     87.142326
# 44    106.837607
# 45    162.764771
# 46    199.646971
# 47    153.846154
# 48    134.894091
# 49     88.721665
# Name: GrLivArea, dtype: float64

# %%
# Create y variable
y= df2['SalePrice']
y
# Out:
# 0     4142895.00
# 1     3606405.00
# 2     4440945.00
# 3     2781800.00
# 4     4967500.00
# 5     2841410.00
# 6     6100090.00
# 7     3974000.00
# 8     2581113.00
# 9     2344660.00
# 10    2573165.00
# 11    6855150.00
# 12    2861280.00
# 13    5553665.00
# 14    3119590.00
# 15    2622840.00
# 16    2960630.00
# 17    1788300.00
# 18    3159330.00
# 19    2761930.00
# 20    6463711.00
# 21    2769878.00
# 22    4570100.00
# 23    2581113.00
# 24    3059980.00
# 25    5092681.00
# 26    2678476.00
# 27    6080220.00
# 28    4123025.00
# 29    1361095.00
# 30     794800.00
# 31    2967584.50
# 32    3574613.00
# 33    3288485.00
# 34    5513925.00
# 35    6139830.00
# 36    2881150.00
# 37    3040110.00
# 38    2165830.00
# 39    1629340.00
# 40    3179200.00
# 41    3377900.00
# 42    2861280.00
# 43    2588067.50
# 44    2801670.00
# 45    6356413.00
# 46    4762560.82
# 47    4961539.00
# 48    2245310.00
# 49    2523490.00
# Name: SalePrice, dtype: float64

# %%
## Generate graph

# Variables x and y

# create scatter plot
plt.plot(x, y, 'o')

#m = slope, b=intercept
m, b = np.polyfit(x, y, 1)

#add line of best fit
plt.plot(x, m*x + b)

# Add title and axis names
plt.title('Living Space vs Sale Price')
plt.xlabel('Living Space')
plt.ylabel('Sale Price')
# Out:
# Text(0, 0.5, 'Sale Price')
